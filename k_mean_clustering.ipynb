# %%
# import libraies
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# generate sample data
X ,y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=0)

# initate a KMeans object with the number of clusters
kmeans = KMeans(n_clusters=4)

# fit the data to make Kmeans algorithm
kmeans.fit(X)

# get the predicated cluster labels for each data point
labels = kmeans.labels_

# plot the data poinds with different colors for different clusters
plt.scatter(X[:, 0], X[:,1], c=labels)
plt.title('K-Means Clustering')
plt.show()

# %% [markdown]
# # **Diamond Dataset**

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# Load dataset
df = sns.load_dataset('diamonds')

# Split data into X
X = df[['carat', 'price']]

# Call the model
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)

# Get the predicated cluster labeles for each data point
labels=kmeans.labels_

# Add predicated cluster labels as a new calumn to the origianal dataset
df['lables'] = labels

# Plot the data points as new colors for different clusters
plt.scatter(X.iloc[:, 0], X.iloc[:,1], c=labels)
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('K-Means Clustering on Diamonds Dataset')
plt.show()

# %% [markdown]
# # **Adding cluster labels to the data for further EDA work**

# %%
df.rename(columns={'lables': 'labels'}, inplace=True)

# %%
df.columns

# %%
# Select relevent columns
X = df[['carat', 'price']]

# model call
kmeans = KMeans(n_clusters=5)

#fit the model
kmeans.fit(X)

# predict cluster
labels = kmeans.predict(X)

# display the first row
print(df.head())

# display the unique values
print('These are the unique values of lables', sorted(df.labels.unique()))

# %% [markdown]
# # **Make a parallel coordinate plot using plotly**

# %%
import plotly.express as px
fig  = px.parallel_coordinates(df, color='labels')
fig.show()
